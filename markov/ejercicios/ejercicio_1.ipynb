# %% [markdown]
# # Ejercicio 1
# En un pueblo, al 90% de los días soleados le siguen días soleados,
# y al 80% de los días nublados le siguen días nublados. Con esta información
# modelar el clima del pueblo como una cadena de Markov.

# %%
from utils.draw_markov import draw_markov_chain

# %%
# Nombres de los estados:
states = ["Soleado", "Nublado"]

# Matriz de transición entre estados:
tiempo = [[0.9, 0.1],
          [0.2, 0.8]]

# Ploteamos el resultado
draw_markov_chain(tiempo, states)
